# %%
import numpy as np
import pandas as pd

pd.set_option('display.float_format', '{:.10f}'.format)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Kepler.csv')

# %%
data_clean = df.copy()

# %%
cols_to_drop = ['kepid', 'kepoi_name', 'kepler_name', 'koi_vet_stat', 'koi_vet_date', 'koi_disp_prov', 'koi_comment',
                'koi_period_err1', 'koi_period_err2', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_time0_err1',
                'koi_time0_err2', 'koi_eccen', 'koi_eccen_err1', 'koi_eccen_err2', 'koi_longp', 'koi_longp_err1',
                'koi_longp_err2', 'koi_ingress', 'koi_ingress_err1', 'koi_ingress_err2', 'koi_incl_err1',
                'koi_incl_err2', 'koi_teq_err1', 'koi_teq_err2', 'koi_limbdark_mod', 'koi_parm_prov',
                'koi_tce_plnt_num', 'koi_tce_delivname', 'koi_quarters', 'koi_trans_mod', 'koi_model_dof',
                'koi_model_chisq', 'koi_smet', 'koi_sage', 'koi_sparprov', 'koi_kepmag', 'koi_gmag', 'koi_rmag',
                'koi_imag', 'koi_zmag', 'koi_jmag', 'koi_hmag', 'koi_kmag']

# %%
brightness_magnitudes = ['koi_kepmag', 'koi_gmag', 'koi_rmag', 'koi_imag', 'koi_zmag', 'koi_jmag', 'koi_hmag',
                         'koi_kmag']

# %%
sns.scatterplot(data=df, x='koi_kepmag', y='koi_imag', hue='koi_disposition')
# Out:
# <Axes: xlabel='koi_kepmag', ylabel='koi_imag'>

# %%
data_clean.drop(columns=cols_to_drop, axis=1, inplace=True)

# %%
data_clean.to_csv('Columns Cleaned.csv', index=False)

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 96 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   rowid               9564 non-null   int64
#  1   koi_disposition     9564 non-null   object
#  2   koi_pdisposition    9564 non-null   object
#  3   koi_score           8054 non-null   float64
#  4   koi_fpflag_nt       9564 non-null   int64
#  5   koi_fpflag_ss       9564 non-null   int64
#  6   koi_fpflag_co       9564 non-null   int64
#  7   koi_fpflag_ec       9564 non-null   int64
#  8   koi_period          9564 non-null   float64
#  9   koi_time0bk         9564 non-null   float64
#  10  koi_time0           9564 non-null   float64
#  11  koi_impact          9201 non-null   float64
#  12  koi_impact_err1     9110 non-null   float64
#  13  koi_impact_err2     9110 non-null   float64
#  14  koi_duration        9564 non-null   float64
#  15  koi_duration_err1   9110 non-null   float64
#  16  koi_duration_err2   9110 non-null   float64
#  17  koi_depth           9201 non-null   float64
#  18  koi_depth_err1      9110 non-null   float64
#  19  koi_depth_err2      9110 non-null   float64
#  20  koi_ror             9201 non-null   float64
#  21  koi_ror_err1        9201 non-null   float64
#  22  koi_ror_err2        9201 non-null   float64
#  23  koi_srho            9243 non-null   float64
#  24  koi_srho_err1       9243 non-null   float64
#  25  koi_srho_err2       9243 non-null   float64
#  26  koi_fittype         9564 non-null   object
#  27  koi_prad            9201 non-null   float64
#  28  koi_prad_err1       9201 non-null   float64
#  29  koi_prad_err2       9201 non-null   float64
#  30  koi_sma             9201 non-null   float64
#  31  koi_sma_err1        0 non-null      float64
#  32  koi_sma_err2        0 non-null      float64
#  33  koi_incl            9200 non-null   float64
#  34  koi_teq             9201 non-null   float64
#  35  koi_insol           9243 non-null   float64
#  36  koi_insol_err1      9243 non-null   float64
#  37  koi_insol_err2      9243 non-null   float64
#  38  koi_dor             9201 non-null   float64
#  39  koi_dor_err1        9110 non-null   float64
#  40  koi_dor_err2        9110 non-null   float64
#  41  koi_ldm_coeff4      9201 non-null   float64
#  42  koi_ldm_coeff3      9201 non-null   float64
#  43  koi_ldm_coeff2      9201 non-null   float64
#  44  koi_ldm_coeff1      9201 non-null   float64
#  45  koi_max_sngle_ev    8422 non-null   float64
#  46  koi_max_mult_ev     8422 non-null   float64
#  47  koi_model_snr       9201 non-null   float64
#  48  koi_count           9564 non-null   int64
#  49  koi_num_transits    8422 non-null   float64
#  50  koi_bin_oedp_sig    8054 non-null   float64
#  51  koi_datalink_dvr    9218 non-null   object
#  52  koi_datalink_dvs    9218 non-null   object
#  53  koi_steff           9201 non-null   float64
#  54  koi_steff_err1      9096 non-null   float64
#  55  koi_steff_err2      9081 non-null   float64
#  56  koi_slogg           9201 non-null   float64
#  57  koi_slogg_err1      9096 non-null   float64
#  58  koi_slogg_err2      9096 non-null   float64
#  59  koi_smet_err1       9177 non-null   float64
#  60  koi_smet_err2       9177 non-null   float64
#  61  koi_srad            9201 non-null   float64
#  62  koi_srad_err1       9096 non-null   float64
#  63  koi_srad_err2       9096 non-null   float64
#  64  koi_smass           9201 non-null   float64
#  65  koi_smass_err1      9096 non-null   float64
#  66  koi_smass_err2      9096 non-null   float64
#  67  koi_sage_err1       0 non-null      float64
#  68  koi_sage_err2       0 non-null      float64
#  69  ra                  9564 non-null   float64
#  70  dec                 9564 non-null   float64
#  71  koi_fwm_stat_sig    8488 non-null   float64
#  72  koi_fwm_sra         9058 non-null   float64
#  73  koi_fwm_sra_err     9058 non-null   float64
#  74  koi_fwm_sdec        9058 non-null   float64
#  75  koi_fwm_sdec_err    9058 non-null   float64
#  76  koi_fwm_srao        9109 non-null   float64
#  77  koi_fwm_srao_err    9109 non-null   float64
#  78  koi_fwm_sdeco       9109 non-null   float64
#  79  koi_fwm_sdeco_err   9109 non-null   float64
#  80  koi_fwm_prao        8734 non-null   float64
#  81  koi_fwm_prao_err    8734 non-null   float64
#  82  koi_fwm_pdeco       8747 non-null   float64
#  83  koi_fwm_pdeco_err   8747 non-null   float64
#  84  koi_dicco_mra       8965 non-null   float64
#  85  koi_dicco_mra_err   8965 non-null   float64
#  86  koi_dicco_mdec      8965 non-null   float64
#  87  koi_dicco_mdec_err  8965 non-null   float64
#  88  koi_dicco_msky      8965 non-null   float64
#  89  koi_dicco_msky_err  8965 non-null   float64
#  90  koi_dikco_mra       8994 non-null   float64
#  91  koi_dikco_mra_err   8994 non-null   float64
#  92  koi_dikco_mdec      8994 non-null   float64
#  93  koi_dikco_mdec_err  8994 non-null   float64
#  94  koi_dikco_msky      8994 non-null   float64
#  95  koi_dikco_msky_err  8994 non-null   float64
# dtypes: float64(85), int64(6), object(5)
# memory usage: 7.0+ MB

# %%
for col in data_clean.columns:
    if data_clean[col].dtype != 'object':
        curr_mean = np.mean(data_clean[col])
        data_clean[col] = data_clean[col].fillna(curr_mean)

# %%
data_clean.isnull().sum()
# Out:
# rowid                 0
# koi_disposition       0
# koi_pdisposition      0
# koi_score             0
# koi_fpflag_nt         0
#                      ..
# koi_dikco_mra_err     0
# koi_dikco_mdec        0
# koi_dikco_mdec_err    0
# koi_dikco_msky        0
# koi_dikco_msky_err    0
# Length: 96, dtype: int64

# %%
data_clean.drop('koi_datalink_dvr', axis=1, inplace=True)
data_clean.drop('koi_datalink_dvs', axis=1, inplace=True)

# %%
data_clean.isnull().sum()
# Out:
# rowid                 0
# koi_disposition       0
# koi_pdisposition      0
# koi_score             0
# koi_fpflag_nt         0
#                      ..
# koi_dikco_mra_err     0
# koi_dikco_mdec        0
# koi_dikco_mdec_err    0
# koi_dikco_msky        0
# koi_dikco_msky_err    0
# Length: 94, dtype: int64

# %%
data_clean.drop('koi_sage_err1', axis=1, inplace=True)
data_clean.drop('koi_sage_err2', axis=1, inplace=True)
data_clean.drop('koi_sma_err1', axis=1, inplace=True)
data_clean.drop('koi_sma_err2', axis=1, inplace=True)

# %%
data_clean.isnull().sum()
# Out:
# rowid                 0
# koi_disposition       0
# koi_pdisposition      0
# koi_score             0
# koi_fpflag_nt         0
#                      ..
# koi_dikco_mra_err     0
# koi_dikco_mdec        0
# koi_dikco_mdec_err    0
# koi_dikco_msky        0
# koi_dikco_msky_err    0
# Length: 90, dtype: int64

# %%
data_clean.drop('koi_pdisposition', axis=1, inplace=True)

# %%
data_clean.isnull().sum()
# Out:
# rowid                 0
# koi_disposition       0
# koi_score             0
# koi_fpflag_nt         0
# koi_fpflag_ss         0
#                      ..
# koi_dikco_mra_err     0
# koi_dikco_mdec        0
# koi_dikco_mdec_err    0
# koi_dikco_msky        0
# koi_dikco_msky_err    0
# Length: 89, dtype: int64

# %%
data_clean.to_csv('NaNs Filled.csv', index=False)

# %%
# Categorical Values
for col in data_clean.columns:
    if data_clean[col].dtype == 'object':
        print(col)
# Out:
# koi_disposition
# koi_fittype

# %%
data_clean['koi_fittype'].value_counts()
# Out:
# koi_fittype
# LS+MCMC    7897
# MCMC       1206
# none        369
# LS           92
# Name: count, dtype: int64

# %%
data_clean_one_hot = pd.concat([data_clean,pd.get_dummies(data_clean['koi_fittype'])], axis=1)

# %%
data_clean_one_hot.drop('koi_fittype', axis=1, inplace=True)

# %%
# Categorical Values
for col in data_clean_one_hot.columns:
    if data_clean_one_hot[col].dtype == 'object':
        print(col)
# Out:
# koi_disposition

# %%
data_clean_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 92 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   rowid               9564 non-null   int64
#  1   koi_disposition     9564 non-null   object
#  2   koi_score           9564 non-null   float64
#  3   koi_fpflag_nt       9564 non-null   int64
#  4   koi_fpflag_ss       9564 non-null   int64
#  5   koi_fpflag_co       9564 non-null   int64
#  6   koi_fpflag_ec       9564 non-null   int64
#  7   koi_period          9564 non-null   float64
#  8   koi_time0bk         9564 non-null   float64
#  9   koi_time0           9564 non-null   float64
#  10  koi_impact          9564 non-null   float64
#  11  koi_impact_err1     9564 non-null   float64
#  12  koi_impact_err2     9564 non-null   float64
#  13  koi_duration        9564 non-null   float64
#  14  koi_duration_err1   9564 non-null   float64
#  15  koi_duration_err2   9564 non-null   float64
#  16  koi_depth           9564 non-null   float64
#  17  koi_depth_err1      9564 non-null   float64
#  18  koi_depth_err2      9564 non-null   float64
#  19  koi_ror             9564 non-null   float64
#  20  koi_ror_err1        9564 non-null   float64
#  21  koi_ror_err2        9564 non-null   float64
#  22  koi_srho            9564 non-null   float64
#  23  koi_srho_err1       9564 non-null   float64
#  24  koi_srho_err2       9564 non-null   float64
#  25  koi_prad            9564 non-null   float64
#  26  koi_prad_err1       9564 non-null   float64
#  27  koi_prad_err2       9564 non-null   float64
#  28  koi_sma             9564 non-null   float64
#  29  koi_incl            9564 non-null   float64
#  30  koi_teq             9564 non-null   float64
#  31  koi_insol           9564 non-null   float64
#  32  koi_insol_err1      9564 non-null   float64
#  33  koi_insol_err2      9564 non-null   float64
#  34  koi_dor             9564 non-null   float64
#  35  koi_dor_err1        9564 non-null   float64
#  36  koi_dor_err2        9564 non-null   float64
#  37  koi_ldm_coeff4      9564 non-null   float64
#  38  koi_ldm_coeff3      9564 non-null   float64
#  39  koi_ldm_coeff2      9564 non-null   float64
#  40  koi_ldm_coeff1      9564 non-null   float64
#  41  koi_max_sngle_ev    9564 non-null   float64
#  42  koi_max_mult_ev     9564 non-null   float64
#  43  koi_model_snr       9564 non-null   float64
#  44  koi_count           9564 non-null   int64
#  45  koi_num_transits    9564 non-null   float64
#  46  koi_bin_oedp_sig    9564 non-null   float64
#  47  koi_steff           9564 non-null   float64
#  48  koi_steff_err1      9564 non-null   float64
#  49  koi_steff_err2      9564 non-null   float64
#  50  koi_slogg           9564 non-null   float64
#  51  koi_slogg_err1      9564 non-null   float64
#  52  koi_slogg_err2      9564 non-null   float64
#  53  koi_smet_err1       9564 non-null   float64
#  54  koi_smet_err2       9564 non-null   float64
#  55  koi_srad            9564 non-null   float64
#  56  koi_srad_err1       9564 non-null   float64
#  57  koi_srad_err2       9564 non-null   float64
#  58  koi_smass           9564 non-null   float64
#  59  koi_smass_err1      9564 non-null   float64
#  60  koi_smass_err2      9564 non-null   float64
#  61  ra                  9564 non-null   float64
#  62  dec                 9564 non-null   float64
#  63  koi_fwm_stat_sig    9564 non-null   float64
#  64  koi_fwm_sra         9564 non-null   float64
#  65  koi_fwm_sra_err     9564 non-null   float64
#  66  koi_fwm_sdec        9564 non-null   float64
#  67  koi_fwm_sdec_err    9564 non-null   float64
#  68  koi_fwm_srao        9564 non-null   float64
#  69  koi_fwm_srao_err    9564 non-null   float64
#  70  koi_fwm_sdeco       9564 non-null   float64
#  71  koi_fwm_sdeco_err   9564 non-null   float64
#  72  koi_fwm_prao        9564 non-null   float64
#  73  koi_fwm_prao_err    9564 non-null   float64
#  74  koi_fwm_pdeco       9564 non-null   float64
#  75  koi_fwm_pdeco_err   9564 non-null   float64
#  76  koi_dicco_mra       9564 non-null   float64
#  77  koi_dicco_mra_err   9564 non-null   float64
#  78  koi_dicco_mdec      9564 non-null   float64
#  79  koi_dicco_mdec_err  9564 non-null   float64
#  80  koi_dicco_msky      9564 non-null   float64
#  81  koi_dicco_msky_err  9564 non-null   float64
#  82  koi_dikco_mra       9564 non-null   float64
#  83  koi_dikco_mra_err   9564 non-null   float64
#  84  koi_dikco_mdec      9564 non-null   float64
#  85  koi_dikco_mdec_err  9564 non-null   float64
#  86  koi_dikco_msky      9564 non-null   float64
#  87  koi_dikco_msky_err  9564 non-null   float64
#  88  LS                  9564 non-null   bool
#  89  LS+MCMC             9564 non-null   bool
#  90  MCMC                9564 non-null   bool
#  91  none                9564 non-null   bool
# dtypes: bool(4), float64(81), int64(6), object(1)
# memory usage: 6.5+ MB

# %%
data_clean_one_hot.to_csv('Processed Data.csv ', index=False)
